# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo-106/blob/main/Equipo_106_P_Final_Avance_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Maestria: Inteligencia artificial aplicada (MNA)
# # Materia:Ciencia Y Analítica de Datos
# # Equipo: 106
# #*   A01793036 - Julian Gongora
# #*   A01793052 - Juan Lopez
#
# # Profesor Titular:Jobish Vallikavungal Devassia
# # Profesor Tutor: Victoria Guerrero Orozco
# # Proyecto final - Avance 1

# %% [markdown]
# # Air Accidents from jan2008 to may2022 - ICAO Data set
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.	El nombre que caracteriza el conjunto de datos:
# **RTA: Air Accidents from jan2008 to may2022 - ICAO**
# 2.	La organización que lo generó: RTA:
# **ICAO (International Civil Aviation Organization)**
# 3.	Incluya un enlace de Internet donde se puedan descargar el base de datos en línea: RTA:
# **https://www.kaggle.com/datasets/marcelotanis/air-accidents-from-jan2008-to-may2022-icao**
# 4.	Describe el conjunto de datos. ¿Qué datos contiene?:
# **RTA: Este es un conjunto de datos de accidentes aéreos (aviones y helicópteros) a nivel mundial, extraídos de OACI en los últimos 15 años. Periodo entre enero de 2008 y mayo de 2022. Entiéndase accidente como un incidente que causa daños graves, lesiones o muertes. Esta base tiene un total 6109 eventos únicos y tiene información de las aeronaves, ruta, operadores, tipo de accidente, fatalidades entre otros.  Tiene 25 columnas por 6109 filas.**
# 5.	Cuáles son algunas de las preguntas de investigación que podría responder con estos datos?:
# - **¿Cuáles son las aeronaves con mayor riesgo de accidente?**
# - **¿Cuáles son los y destinos con mayor riesgo de accidente?**
# - **¿Cuáles son las aerolíneas con mayor accidentalidad?**
# - **¿Cuáles son las locaciones (Países-ciudades-Aeropuertos) con mayor accidentalidad?**
# - **¿Cuál es la fase de vuelo con más accidentes?**
# - **¿Existe una correlación en el accidente entre la aeronave y la fase de vuelo para sugerir acciones de mejora?**
# - **¿Existe una correlación en el accidente entre la fase de vuelo y el lugar para sugerir acciones de mejora?**
# - **¿Cuáles son los tipos de riesgos más populares y tienen alguna correlación con aeronave, operador o locación? **bold text**
# 6.	¿Qué actor (empresa, sector de la sociedad, organismo descentralizado, gobierno, etc.) estaría interesado en las preguntas mencionadas que identificó?
# - **Organizaciones internacionales (como la ONU), organizaciones internacionales de aviación, organizaciones internacionales de transporte.**
# - **Gobiernos de Estados y entidades regulatorias de aviación Civiles locales.**
# - **Aeropuertos y operadores de aeropuertos.**
# - **Aerolíneas.**
# - **Público en general.**
