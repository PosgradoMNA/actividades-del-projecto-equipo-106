# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # Maestria: Inteligencia artificial aplicada (MNA)
# # Materia:Ciencia Y Analítica de Datos
# # Alumnos:
# #* A01793036 - Julian Gongora
# #* A01793052 - Juan Lopez
# # Profesor Titular:Jobish Vallikavungal Devassia
# # Profesor Tutor: Victoria Guerrero Orozco
# # Equipo: Equipo 106
# # Semana 3 - Actividad 1: Parte 2: Selección y limpieza de los Datos en Python

# %% [markdown]
# #Parte 1: Fundamentos de bases de datos

# %% [markdown]
# *1.1¿Que es una base de datos?*
# - Oracle define una base de datos como  una recopilación organizada de información o datos estructurado. Normalmente, una base de datos está controlada por un sistema de gestión de bases de datos (DBMS).
#
# *1.2¿Que es un data warehouse?*
# -	Amazon expone en su artículo que un data warehouse es palabras simples: un repositorio que centraliza la información. Esta data generalmente es producto de una operación corporativa y tiene como objetivo facilitar la toma de decisiones establecidas en datos. Este hub de información es alimentado constantemente por sistemas transaccionales, bases de datos relacionales, y otras fuentes.
#
#
# *1.3¿Como funciona un data warehouse?*
# -	Metwalli afirma que para entender el funcionamiento se puede ver desde dos tipos de bases:
# > Las bases *no relacionales*: Son aquellas que guardan la información en categorías, en lugar de relaciones. Son conocidas como No SQL. Algunos ejemplos: Rabit MQ, Mongo DB, Janus Graph.
# > Las bases relacionales: son aquellas que guardan información en tablas, las cuales están relacionadas. Algunos ejemplos son: Postgrade SQL, MySQL, DB2.
#
# *1.4¿Cuales son los beneficios de utilizar un data warehouse?*
#
# -	Kane dice que la data se de normalizar, esto significa responder cómo se relacionan entre sí todos los campos en estas diferentes fuentes de datos. Lo que favorece a una organización en:
# >Facilita el análisis de datos y la posterior toma de decisiones.
# >Agrega una mayor velocidad al acceso de la información.
# >Permite tener una visión partículas y general de la operación de la organización.
# >Aporta insigths para la proyección y planeación.
# >Puede llegar a proveer información y perspectivas de solución a problemas de la organización.

# %% [markdown]
# Bibliografía:
#
# -	Kane, F. (2017). Hands-on data science and python machine learning. Packt Publishing Ltd.
# -	AWS, (NA) Data Warehouse Concepts, web: https://aws.amazon.com/data-warehouse/
# -	Metwalli, Sara A. 2020 Septiembre, Databases 101: Introduction to Databases for Data Scientists, Towards Data Science, Web link https://towardsdatascience.com/databases-101-introduction-to-databases-for-data-scientists-ee18c9f0785d
# - Oracle, (NA), ¿Qué es una base de datos? (s/f). Oracle.com. Recuperado el 5 de octubre de 2022, de https://www.oracle.com/co/database/what-is-database/

# %% [markdown]
# # Parte 2: Selección y limpieza de los Datos en Python

# %% [markdown]
# Data Set Information:
#
# This research aimed at the case of customers default payments in Taiwan and compares the predictive accuracy of probability of default among six data mining methods. From the perspective of risk management, the result of predictive accuracy of the estimated probability of default will be more valuable than the binary result of classification - credible or not credible clients. Because the real probability of default is unknown, this study presented the novel â€œSorting Smoothing Methodâ€ to estimate the real probability of default. With the real probability of default as the response variable (Y), and the predictive probability of default as the independent variable (X), the simple linear regression result (Y = A + BX) shows that the forecasting model produced by artificial neural network has the highest coefficient of determination; its regression intercept (A) is close to zero, and regression coefficient (B) to one. Therefore, among the six data mining techniques, artificial neural network is the only one that can accurately estimate the real probability of default.
#
#
# Attribute Information:
#
# This research employed a binary variable, default payment (Yes = 1, No = 0), as the response variable. This study reviewed the literature and used the following 23 variables as explanatory variables:
#
# X1: Amount of the given credit (NT dollar): it includes both the individual consumer credit and his/her family (supplementary) credit.
#
# X2: Gender (1 = male; 2 = female).
#
# X3: Education (1 = graduate school; 2 = university; 3 = high school; 4 = others.
#
# X4: Marital status (1 = married; 2 = single; 3 = others).
#
# X5: Age (year).
#
# X6 - X11: History of past payment. We tracked the past monthly payment records (from April to September, 2005) as follows: X6 = the repayment status in September, 2005;X7 = the repayment status in August, 2005; . . .; X11 = the repayment status in April, 2005. The measurement scale for the repayment status is: -1 = pay duly; 1 = payment delay for one month; 2 = payment delay for two months; . . .; 8 = payment delay for eight months; 9 = payment delay for nine months and above.
#
# X12-X17: Amount of bill statement (NT dollar). X12 = amount of bill statement in September, 2005; X13 = amount of bill statement in August, 2005; . . .; X17 = amount of bill statement in April, 2005.
#
# X18-X23: Amount of previous payment (NT dollar). X18 = amount paid in September, 2005; X19 = amount paid in August, 2005; . . .;X23 = amount paid in April, 2005.
#
#
# Relevant Papers:
#
# Yeh, I. C., & Lien, C. H. (2009). The comparisons of data mining techniques for the predictive accuracy of probability of default of credit card clients. Expert Systems with Applications, 36(2), 2473-2480.
#
#
#
# Citation Request:
#
# Yeh, I. C., & Lien, C. H. (2009). The comparisons of data mining techniques for the predictive accuracy of probability of default of credit card clients. Expert Systems with Applications, 36(2), 2473-2480

# %%
#Se carga la base de datos en la variable imput.
input="https://raw.githubusercontent.com/PosgradoMNA/Actividades_Aprendizaje-/main/default%20of%20credit%20card%20clients.csv"

# %%
#Carga de librerias
import pandas as pd
import numpy as np

# %%
#Lectura de los datos del archivo
df=pd.read_csv(input)
df
#La tabla de abajo se convirtio en interactiva para mejor visualizacion
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %%
#Verificamos si falta algun dato
df.isnull().values.any()
# Out:
# True

# %%
df.isna().any()
# Out:
# ID     False
# X1     False
# X2      True
# X3      True
# X4      True
# X5      True
# X6      True
# X7      True
# X8      True
# X9      True
# X10     True
# X11     True
# X12     True
# X13     True
# X14     True
# X15     True
# X16     True
# X17     True
# X18     True
# X19     True
# X20     True
# X21     True
# X22     True
# X23     True
# Y       True
# dtype: bool

# %% [markdown]
# Se observa que X1 no tiene datos pendientes ni la columna IDE pero todas las demas tienen datos faltantes

# %% [markdown]
# **Solución Propuesta para limpieza de datos**

# %%
#Descartar las observaciones con valores faltantes
sol=df.copy()
sol.dropna(inplace = True)
sol
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %%
sol1.isna().any()
# Out:
# ID     False
# X1     False
# X2     False
# X3     False
# X4     False
# X5     False
# X6     False
# X7     False
# X8     False
# X9     False
# X10    False
# X11    False
# X12    False
# X13    False
# X14    False
# X15    False
# X16    False
# X17    False
# X18    False
# X19    False
# X20    False
# X21    False
# X22    False
# X23    False
# Y      False
# dtype: bool

# %% [markdown]
# **Conclusiones:**
# 1. El método que se utilizo para limpiar los datos fue la eliminación de filas con almenos un dato faltante mediante la funcion Dropna.
#
# 2. El resultado fue que elimino 42 filas (0.14% del total de las filas), esta decisión se tomo por que los datos de la base de datos no son continuos es decir partiendo del entendimiento que la salida es el incumplimiento o cumplimiento del pago del cliente respecto a las variables X1 a X23, no existe una dependencia entre clientes es decir si un cliente paga no depende de que el pasado o el nuevo pague o no pague.
# 3. Por lo cual la eliminación de los datos pendientes resulta una  solución adecuada para esta base de datos comparada con la técnica de sustitución de datos, con el comando fillna, revisando el set de datos contine columnas con diferentes datos por ejemplo el genero X2 donde 1 representa masculino y 2 representa femenino donde tal vez remplazarlos con un valor promedio agregaría un genero que no lo incluye en ese caso podría recomendar usar la mediana y deberíamos analizar cada caso.
# 4. Se resalta que en la columna de pago (salida Y) existen inconsistencias en algunas filas, estas filas se deben descartar ya que no se puede estimar si el deudor pago o no.

# %% [markdown]
# # Parte 3: Preparación de los datos

# %% [markdown]
# Con base en los resultados de tu libreta de Google Colab de la Parte 2 responde detalladamente las siguientes preguntas:
#
# **3.1 ¿Qué datos considero más importantes? ¿Por qué?**
#
# *Desde nuestro punto de vista, los datos que muestran 1. Importe del estado de cuenta (las columnas x12-x17), 2. monto de pago anterior (x18-x-23) no son datos categóricos o binarios los cuales tienen mayor separación y podrían mostrar algún patrón que ayude para la predicción de la salida o aporten mayor peso a ella cosa que no sabremos hasta que se genere el modelo y observemos su comportamiento.
#
# **3.2 ¿Se eliminaron o reemplazaron datos nulos? ¿Qué se hizo y por qué?**
#
# *Se eliminaron los datos tal como muestra la conclusión de la solución se mostro una perdida de 0.14% de filas del total de 30K filas y no hubo eliminación de columnas, lo cual nos lleva a pensar que no fue grande la perdida de datos y al no ser datos continuos o dependientes entre filas la perdida de estos datos no es relevante para el análisis.
#
# Teniendo encuenta que los eventos de pago son eventos independientes. Es decir no dependen pagador anterior, se considera que no resulta util el aplicar el remplazo de datos.
#
# **3.3 ¿Es necesario limpiar los datos para el análisis? Sí / No / ¿Por qué?**
#
# *Por supuesto es necesario limpiar datos como dice la primera parte del modulo si tu metes basura al modelo vas a obtener basura, esa es la principal razón por la cual debemos limpiar los datos ya sea eliminado las filas faltantes si no son datos continuos o agregar valores con respecto a la media, mediana o valores máximos o mínimos en los datos faltantes analizando la información que tiene la columna.
#
# **3.4 ¿Existen problemas de formato que deban solucionar antes del proceso de modelado? Sí / No / Por qué.**
#
# *Si, debido a que se debe revisar si los datos de las columnas cumplen con los criterios establecidos en la información por ejemplo si el formato es una categoría que va de 1 o 2 se debe asegurar que los datos contenidos en esa columna contengan ese rango.
#
# **3.5 ¿Qué ajustes se realizaron en el proceso de limpieza de datos (agregar, integrar, eliminar, modificar registros (filas), cambiar atributos (columnas)?**
#
# *Se eliminaron las filas que contenían al menos un dato NAN, ya que no se considero una gran perdida de datos y se establecio que estos datos no son continuos como datos capturados durante el tiempo se pueden eliminar los faltantes y un punto importante es que había salidas faltantes, agregar valores a estas salidas usando las técnicas revisadas puede provocar ruido en la salida simplemente analizando valores de la misma columna.
